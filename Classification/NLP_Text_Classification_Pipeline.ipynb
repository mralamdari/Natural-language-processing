# %% [markdown]
# <a href="https://colab.research.google.com/github/mralamdari/NLP-Text_Classification/blob/main/NLP_Text_Classification_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import string
import sklearn
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.cm as cm
import warnings
warnings.filterwarnings('ignore')

from sklearn import svm
from sklearn import metrics
from sklearn import pipeline
from sklearn import naive_bayes
from sklearn import linear_model
from sklearn import feature_extraction
from sklearn import model_selection

# %%
# !wget -P DATAPATH https://raw.githubusercontent.com/practical-nlp/practical-nlp/master/Ch4/Data/Full-Economic-News-DFE-839861.csv
# !ls -lah DATAPATH
data = pd.read_csv("DATAPATH/Full-Economic-News-DFE-839861.csv" , encoding = "ISO-8859-1" )

# %%
data
# Out:
#        _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0     842613455    False   finalized                   3     12/5/15 17:48
# 1     842613456    False   finalized                   3     12/5/15 16:54
# 2     842613457    False   finalized                   3      12/5/15 1:59
# 3     842613458    False   finalized                   3      12/5/15 2:19
# 4     842613459    False   finalized                   3     12/5/15 17:48
# ...         ...      ...         ...                 ...               ...
# 7995  830985632    False   finalized                   3    11/17/15 18:16
# 7996  830985633    False   finalized                   3     11/18/15 8:10
# 7997  830985634    False   finalized                   3    11/18/15 12:12
# 7998  830985635    False   finalized                   3     11/18/15 7:17
# 7999  830985636    False   finalized                   3    11/18/15 11:05
#
#       positivity  positivity:confidence relevance  relevance:confidence  \
# 0            3.0                 0.6400       yes                0.6400
# 1            NaN                    NaN        no                1.0000
# 2            NaN                    NaN        no                1.0000
# 3            NaN                 0.0000        no                0.6750
# 4            3.0                 0.3257       yes                0.6400
# ...          ...                    ...       ...                   ...
# 7995         7.0                 0.3511       yes                0.6641
# 7996         NaN                    NaN        no                1.0000
# 7997         NaN                    NaN        no                1.0000
# 7998         NaN                 0.0000        no                0.6855
# 7999         NaN                    NaN        no                1.0000
#
#            articleid      date  \
# 0      wsj_398217788   8/14/91
# 1      wsj_399019502   8/21/07
# 2      wsj_398284048  11/14/91
# 3      wsj_397959018   6/16/86
# 4      wsj_398838054   10/4/02
# ...              ...       ...
# 7995  wapo_152454634   2/11/52
# 7996  wapo_410349039  12/13/09
# 7997  wapo_410346237  12/18/09
# 7998  wapo_307808606   1/10/95
# 7999  wapo_143151328   4/18/67
#
#                                                headline  positivity_gold  \
# 0                 Yields on CDs Fell in the Latest Week              NaN
# 1     The Morning Brief: White House Seeks to Limit ...              NaN
# 2     Banking Bill Negotiators Set Compromise --- Pl...              NaN
# 3     Manager's Journal: Sniffing Out Drug Abusers I...              NaN
# 4     Currency Trading: Dollar Remains in Tight Rang...              NaN
# ...                                                 ...              ...
# 7995  Sawyer Sees Strong Economy For 2 Years, Truce ...              NaN
# 7996                   Oil's losses are airlines' gains              NaN
# 7997  Full Senate to vote on Bernanke; PANEL ADVANCE...              NaN
# 7998                          Reinventing Opportunities              NaN
# 7999  Stocks Rise On News of Auto Output: Dow Climbs...              NaN
#
#       relevance_gold                                               text
# 0                NaN  NEW YORK -- Yields on most certificates of dep...
# 1                NaN  The Wall Street Journal Online</br></br>The Mo...
# 2                NaN  WASHINGTON -- In an effort to achieve banking ...
# 3                NaN  The statistics on the enormous costs of employ...
# 4                NaN  NEW YORK -- Indecision marked the dollar's ton...
# ...              ...                                                ...
# 7995             NaN  Secretary of Commerce Charles W. Sawyer said y...
# 7996             NaN  U.S. stocks inched up last week, overcoming co...
# 7997             NaN  Ben S. Bernanke cleared a key hurdle Thursday ...
# 7998             NaN  The White House's push to contract out many fe...
# 7999             NaN  NEW YORK. April 17-Automobile stocks put on th...
#
# [8000 rows x 15 columns]

# %%
data.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'positivity', 'positivity:confidence', 'relevance',
#        'relevance:confidence', 'articleid', 'date', 'headline',
#        'positivity_gold', 'relevance_gold', 'text'],
#       dtype='object')

# %%
data.shape
# Out:
# (8000, 15)

# %%
100*data.relevance.value_counts() / data.shape[0]
# Out:
# no          82.1375
# yes         17.7500
# not sure     0.1125
# Name: relevance, dtype: float64

# %%
data.relevance.value_counts()
# Out:
# no          6571
# yes         1420
# not sure       9
# Name: relevance, dtype: int64

# %%
#remove 'not sure' from dataset (it is just 9 data)
data = data[data.relevance != 'not sure']

# %%
data['relevance'] = data.relevance.map({'yes': 1, 'no': 0})
data = data[['text', 'relevance']]

# %%
data
# Out:
#                                                    text  relevance
# 0     NEW YORK -- Yields on most certificates of dep...          1
# 1     The Wall Street Journal Online</br></br>The Mo...          0
# 2     WASHINGTON -- In an effort to achieve banking ...          0
# 3     The statistics on the enormous costs of employ...          0
# 4     NEW YORK -- Indecision marked the dollar's ton...          1
# ...                                                 ...        ...
# 7995  Secretary of Commerce Charles W. Sawyer said y...          1
# 7996  U.S. stocks inched up last week, overcoming co...          0
# 7997  Ben S. Bernanke cleared a key hurdle Thursday ...          0
# 7998  The White House's push to contract out many fe...          0
# 7999  NEW YORK. April 17-Automobile stocks put on th...          0
#
# [7991 rows x 2 columns]

# %%
stopwords = sklearn.feature_extraction._stop_words.ENGLISH_STOP_WORDS
def data_processing(doc):
  # try:
  #   doc = doc.replace("</br>", " ")
  # except AttributeError:
  #   doc = doc[0].replace("</br>", " ")

  doc = doc.replace("</br>", " ")
  doc = "".join([char for char in doc if char not in string.punctuation and not char.isdigit()])
  doc = " ".join([token for token in doc.split() if token not in stopwords])
  return doc

# %%
x = data.text
y = data.relevance
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, random_state=23, test_size=0.25)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (5993,) (5993,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (1998,) (1998,)

# %%
vect = feature_extraction.text.CountVectorizer(preprocessor=data_processing)

x_train_dtm = vect.fit_transform(x_train)
x_test_dtm = vect.transform(x_test)

print(x_train_dtm.shape, x_test_dtm.shape)
# Out:
# (5993, 49755) (1998, 49755)

# %%
print(len(vect.get_feature_names_out()))
vect.get_feature_names_out()
# Out:
# 49755
# array(['AA', 'AAA', 'AACER', ..., 'åÈi', 'åÈn', 'åÈut'], dtype=object)

# %%
print(len(vect.get_feature_names()))
vect.get_feature_names()[20:40]
# Out:
# 49755
# ['ABU',
#  'ABkLtFI',
#  'ABkTPa',
#  'ABkrFla',
#  'AC',
#  'ACAPULCO',
#  'ACCB',
#  'ACLU',
#  'ACORN',
#  'ACQUIRES',
#  'ACS',
#  'ACSs',
#  'ACTUAL',
#  'ACoLl',
#  'ACtyBk',
#  'AD',
#  'ADA',
#  'ADC',
#  'ADD',
#  'ADEAR']

# %%
naive_bayes_model = naive_bayes.MultinomialNB()
naive_bayes_model.fit(x_train_dtm, y_train)
naive_bayes_predict = naive_bayes_model.predict(x_test_dtm)

# %%
100 * metrics.accuracy_score(y_test, naive_bayes_predict)
# Out:
# 77.92792792792793

# %%
def confusion_mat(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
  
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.0
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt), horizontalalignment='center', color='white' if cm[i, j]>thresh else 'black')
  plt.tight_layout()
  plt.ylabel('True Label', fontsize=15)
  plt.xlabel('Predicted Label', fontsize=15)

# %%
print('Accuracy: ', metrics.accuracy_score(y_test, naive_bayes_predict))

cnf_matrix = metrics.confusion_matrix(y_test, naive_bayes_predict)
plt.figure(figsize=(8, 6))
confusion_mat(cnf_matrix, classes=['Not Relevant', 'Relevant'],
                      normalize=True, title='Confusion matrix with all fatures')

print('ROC AUC Score: ', metrics.roc_auc_score(y_test, naive_bayes_predict))
# Out:
# Accuracy:  0.7792792792792793
# ROC AUC Score:  0.6324957693920941

# %%
vect = feature_extraction.text.CountVectorizer(preprocessor=data_processing, max_features=5000)
x_train_dtm = vect.fit_transform(x_train)
x_test_dtm = vect.transform(x_test)
nb_model = naive_bayes.MultinomialNB()
nb_model.fit(x_train_dtm, y_train)
y_pred = nb_model.predict(x_test_dtm)

print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
confusion_mat(cnf_matrix, classes=['Not Relevant', 'Relevant'],
                      normalize=True, title='Confusion matrix with 5000 fatures')

print('ROC AUC Score: ', metrics.roc_auc_score(y_test, y_pred))
# Out:
# Accuracy:  0.6901901901901902
# ROC AUC Score:  0.6767526287623483

# %%
lr_model = linear_model.LogisticRegressionCV(class_weight='balanced')
lr_model.fit(x_train_dtm, y_train)
y_pred = lr_model.predict(x_test_dtm)

print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
confusion_mat(cnf_matrix, classes=['Not Relevant', 'Relevant'],
                      normalize=True, title='Confusion matrix with 5000 fatures')

print('ROC AUC Score: ', metrics.roc_auc_score(y_test, y_pred))
# Out:
# Accuracy:  0.7382382382382382
# ROC AUC Score:  0.6030623092610539

# %%
vect = feature_extraction.text.CountVectorizer(preprocessor=data_processing, max_features=1000)
x_train_dtm = vect.fit_transform(x_train)
x_test_dtm = vect.transform(x_test)
svm_model = svm.LinearSVC(class_weight='balanced')
svm_model.fit(x_train_dtm, y_train)
y_pred = svm_model.predict(x_test_dtm)

print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
confusion_mat(cnf_matrix, classes=['Not Relevant', 'Relevant'],
                      normalize=True, title='Confusion matrix with 5000 fatures')

print('ROC AUC Score: ', metrics.roc_auc_score(y_test, y_pred))
# Out:
# Accuracy:  0.6766766766766766
# ROC AUC Score:  0.6023246648056813

# %% [markdown]
# ##Interpreting predictions with Lime

# %%
# !pip install lime
import lime

# %%
from lime.lime_text import LimeTextExplainer
c = pipeline.make_pipeline(vect, lr_model)
print(c.predict_proba([x_test[76]]))
class_names = ['no', 'yes']
explainer = LimeTextExplainer(class_names=class_names)
exp = explainer.explain_instance(x_test[76], c.predict_proba, num_features=10)
# Out:
# [[0.86244754 0.13755246]]

# %%
fig = exp.as_pyplot_figure()

# %% [markdown]
# ##Interpreting predictions with Shap

# %% [markdown]
# ####The SHAP value plot can further show the positive and negative relationships of the predictors with the target variable.
#
# This plot is made of all the dots in the train data. It demonstrates the following information:
#
# #####1.Feature importance: Variables are ranked in descending order from the most important decreasing to the least.
# #####2.Impact: The horizontal location shows what effect the fature has with respect to prediction (higher or lower prediction).
# #####3.Original value: Color shows whether that variable is high (in red) or low (in blue) for that observation.
# #####4.Correlation: The presence of the word "dollar" has a high (positive) impact in deciding whether the article is relavent to the USA economy.

# %%
# !pip install shap

# %%
import shap
explainer = shap.LinearExplainer(lr_model, x_train_dtm, feature_perturbation='interventional')
shap_values = explainer.shap_values(x_test_dtm)
x_test_array = x_test_dtm.toarray()

# %%
shap.initjs()
shap.summary_plot(shap_values, x_test_array, feature_names=vect.get_feature_names())
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
shap.initjs()

shap.force_plot(
    explainer.expected_value, shap_values[0,:], x_test_array[0,:],
    feature_names=vect.get_feature_names())
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i2XOTKIPYDELKXTJ5RPWC'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.6329298971843658, "outValue": -2.876483477572404, "link": "identity", "featureNames": ["AFLCIO", "AG", "AIG", "AMR", "AOL", "AP", "ARMs", "ATT", "About", "According", "Accounting", "Act", "Administration", "Advancing", "Advisers", "Advisors", "Affairs", "Afghanistan", "Africa", "After", "Agency", "Agriculture", "Air", "Airlines", "Airways", "Alan", "Alcoa", "Alexandria", "Alfred", "All", "Allen", "Almost", "Also", "Although", "America", "American", "Americans", "Americas", "Amex", "Among", "Amplifications", "An", "Analysis", "Analysts", "And", "Anderson", "Andrew", "Angeles", "Another", "Anthony", "Any", "Apple", "Appropriations", "April", "Arab", "Argentina", "Arizona", "Arlington", "Arthur", "As", "Asia", "Asian", "Asias", "Assembly", "Asset", "Associated", "Associates", "Association", "At", "Atlanta", "Atlantic", "Aug", "August", "Australia", "Australian", "Author", "Auto", "Avenue", "Average", "BCCI", "BLS", "Back", "Baker", "Baltimore", "Bank", "Bankers", "Banking", "Banks", "Barack", "Barclays", "Barney", "Barry", "Bay", "Bear", "Because", "Before", "Behind", "Beijing", "Bell", "Ben", "Bentsen", "Bernanke", "Bernankes", "Bethesda", "Biden", "Big", "Bill", "Black", "Blue", "Bluechip", "Board", "Boards", "Bob", "Boeing", "Bond", "Bonds", "Boston", "Both", "Brady", "Brazil", "Brian", "Britain", "British", "Broader", "Brokers", "Brookings", "Brooks", "Brothers", "Brown", "Bruce", "Budget", "Buffett", "Building", "Bundesbank", "Bureau", "Burns", "Bush", "Bushs", "Business", "Businesses", "But", "By", "CBO", "CBS", "CD", "CDs", "CEO", "CEOs", "COLA", "CPI", "Cabinet", "Calif", "California", "Californias", "Call", "Can", "Canada", "Canadas", "Canadian", "Capital", "Capitol", "Carl", "Carolina", "Carter", "Caterpillar", "Census", "Center", "Central", "Chairman", "Chamber", "Chapter", "Charles", "Charlotte", "Chase", "Chemical", "Chicago", "Chief", "China", "Chinas", "Chinese", "Chris", "Christian", "Christmas", "Christopher", "Chrysler", "Circuit", "Cisco", "Citibank", "Citicorp", "Citigroup", "Citizens", "City", "Civil", "Clearly", "Cleveland", "Clinton", "Clintons", "Club", "Co", "Coast", "Cohen", "Col", "Cold", "College", "Columbia", "Commerce", "Commission", "Commissioner", "Committee", "Commodity", "Communications", "Communist", "Community", "Companies", "Company", "Composite", "Comptroller", "Computer", "Conference", "Congress", "Congressional", "Conn", "Connecticut", "Consider", "Consumer", "Consumers", "Continental", "Cooperation", "Corp", "Corporate", "Corps", "Corrections", "Cos", "Council", "Countries", "County", "Court", "Credit", "Currency", "Currently", "DC", "DTex", "Dallas", "Dan", "Daniel", "Data", "David", "Davis", "Day", "Dealers", "Dean", "Dec", "December", "Declines", "Declining", "Defense", "Del", "Demand", "Democrat", "Democratic", "Democrats", "Department", "Departments", "Deposit", "Depot", "Depression", "Despite", "Detroit", "Deutsche", "Development", "Director", "Disney", "District", "Districts", "Division", "Do", "Dodd", "Dole", "Dollar", "Donald", "Dont", "Douglas", "Dow", "DowJones", "Dr", "Drexel", "Drug", "Du", "DuPont", "Dukakis", "During", "ECB", "EDT", "Each", "Earlier", "East", "Eastern", "Economic", "Economics", "Economist", "Economists", "Economy", "Education", "Edward", "Edwards", "Ehrlich", "Eisenhower", "El", "Electric", "Employees", "Employment", "Energy", "England", "English", "Equity", "Eric", "Estate", "Eurodollar", "Europe", "European", "Europes", "Evans", "Even", "Every", "Everyone", "Exchange", "Exchanges", "Excluding", "Executive", "Executives", "Exporting", "Exports", "Express", "Exxon", "FDIC", "FOMC", "Facebook", "Fairfax", "Family", "Fannie", "Fargo", "Feb", "February", "Fed", "Federal", "Federation", "Feds", "Fidelity", "Finance", "Financial", "First", "Fisher", "Five", "Fla", "Florida", "Following", "Food", "For", "Ford", "Fords", "Foreign", "Foundation", "Four", "Fox", "France" ...

# %% [markdown]
# #####The output value is the prediction for that observation (the prediction of the first row in Table B is -2.88).
#
# #####1.The base value: The original paper explains that the base value E(y_hat) is “the value that would be predicted if we did not know any features for the current output.” In other words, it is the mean prediction, or mean(yhat).
# #####2.Red/blue: Features that push the prediction higher are shown in blue, and those pushing the prediction lower are in red.
# #####3.Economy: Has a negative impact on deciding if the article is relavent for US Economy. So it pushes the prediction to the left.
